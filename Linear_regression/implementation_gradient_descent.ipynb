# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
dx = pd.read_csv('linearX.csv')
dy = pd.read_csv('linearY.csv')

# %%
print(dx.shape)
print(dy.shape)
# converting into numpy array
x = dx.values
y = dy.values
# Out:
# (99, 1)
# (99, 1)

# %% [markdown]
# ##### visualizing and preprocessing

# %%
#normalizing
x = (x - x.mean())/x.std()

# %%
#  ploting
plt.scatter(x, y)

# %% [markdown]
# ## Gradient Descent
# - start with random data
# - repeat until convergence
#     - update theta accordung to rule

# %%
def hypothesis(x, theta):
    return theta[0] + theta[1]*x

def error(x, y, theta):
    err = 0
    for i in range(x.shape[0]):
        hx = hypothesis(x[i], theta)
        err += (hx - y[i])**2
    return err/2

def gradient(x, y, theta):
    grad = np.zeros(theta.shape)
    for i in range(x.shape[0]):
        hx = hypothesis(x[i], theta)
        grad[0] += (hx - y[i])
        grad[1] += (hx - y[i])*x[i]
    return grad

def gradient_descent(x, y, learning_rate = 0.0001):
    theta = np.zeros(2)
    max_itr = 1000
    err = []
    for i in range(max_itr):
        grad = gradient(x, y, theta)
        err.append(error(x, y, theta)) 
        theta[0] = theta[0] - learning_rate*grad[0]
        theta[1] = theta[1] - learning_rate*grad[1]
    return theta, err
theta, err = gradient_descent(x, y)

# %%
plt.plot(err)

# %%
print(theta)
# Out:
# [0.99658654 0.00135787]

# %%
line_x = np.arange(-3, 7)
# print(line_x)
plt.plot(line_x, hypothesis(line_x, theta), color = 'r')
plt.scatter(x, y)
